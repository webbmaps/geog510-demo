# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/USERNAME/REPOSITORY/blob/BRANCH/PATH_TO_NOTEBOOK.ipynb)

# %%
# Simple leafmap set to the University of Tenessee that GEOG 510 students can use for the open source pull request for lab 2

import leafmap


m = leafmap.Map(center=[35.9544, -83.9295], zoom=15)

m
